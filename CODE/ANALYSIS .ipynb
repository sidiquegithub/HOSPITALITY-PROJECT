# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
#ALL FILES IN DIRECTORY

directory_path = r"C:\Users\sidiq\OneDrive\Desktop\HOSPITALITY\DATA"

files = [file for file in os.listdir(directory_path)]

for file in files:
    print(file)
# Out:
# dim_date.csv
# dim_hotels.csv
# dim_rooms.csv
# fact_aggregated_bookings.csv
# fact_bookings.csv
# meta_data_hospitality.txt
# metrics list.xlsx

# %%
# Create DataFrames for CSV files
csv_files = [file for file in files if file.endswith(".csv")]

for csv_file in csv_files:
    file_path = os.path.join(directory_path, csv_file)
    name = os.path.splitext(csv_file)[0]  # Use file name as DataFrame name
    globals()[name] = pd.read_csv(file_path)
    print(f"{name} DataFrame created.")
# Out:
# dim_date DataFrame created.
# dim_hotels DataFrame created.
# dim_rooms DataFrame created.
# fact_aggregated_bookings DataFrame created.
# fact_bookings DataFrame created.

# %%
# Rename dataframe 
hotels = dim_hotels
rooms = dim_rooms
date = dim_date
df_1 = fact_aggregated_bookings
df_2 = fact_bookings

# %%
# Let us look into each dataframe

# %%
hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df_1
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559     01-May-22           RT1                   25        30
# 1           19562     01-May-22           RT1                   28        30
# 2           19563     01-May-22           RT1                   23        30
# 3           17558     01-May-22           RT1                   13        19
# 4           16558     01-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
df_2
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
# Let us make some changes the dataframe date

# %%
# Convert date fromat in the datarame date

date['date'] = pd.to_datetime(date['date'], format='%d-%b-%y')

# Convert the 'date' column to the desired format
date['date'] = date['date'].dt.strftime('%Y-%m-%d')

# Display the updated DataFrame
date.head()
# Out:
#          date  mmm yy week no  day_type
# 0  2022-05-01  May 22    W 19   weekend
# 1  2022-05-02  May 22    W 19  weekeday
# 2  2022-05-03  May 22    W 19  weekeday
# 3  2022-05-04  May 22    W 19  weekeday
# 4  2022-05-05  May 22    W 19  weekeday

# %%
# Now to find mapping between week no and month

# %%
# Check for July Month
May = date[date['mmm yy'] == "May 22"]['week no'].unique()
May
# Out:
# array(['W 19', 'W 20', 'W 21', 'W 22', 'W 23'], dtype=object)

# %%
June = date[date['mmm yy'] == "Jun 22"]['week no'].unique()
June
# Out:
# array(['W 23', 'W 24', 'W 25', 'W 26', 'W 27'], dtype=object)

# %%
# Check for July Month
July = date[date['mmm yy'] == "Jul 22"]['week no'].unique()
July
# Out:
# array(['W 27', 'W 28', 'W 29', 'W 30', 'W 31', 'W 32'], dtype=object)

# %%
# This shows week 19 to 23 is for May, Week 23 to 27 to June and Week 27 to 32 for July.

# %%
# Let us make some changes in df_1 dataframe

# %%
# Convert date fromat in the datarame df_1

df_1['check_in_date'] = pd.to_datetime(df_1['check_in_date'] , format='%d-%b-%y')

# Convert the 'date' column to the desired format
df_1['check_in_date']  = df_1['check_in_date'] .dt.strftime('%Y-%m-%d')

# Display the updated DataFrame
df_1.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559    2022-05-01           RT1                   25        30
# 1        19562    2022-05-01           RT1                   28        30
# 2        19563    2022-05-01           RT1                   23        30
# 3        17558    2022-05-01           RT1                   13        19
# 4        16558    2022-05-01           RT1                   18        19

# %%
# Add coloumns to df_1 dataframe.

# %%
# Now add the column week no and day_type column from the dataframe date to the dataframes df_1 and df_2.
# This is done using merge

# Merge based on 'date' and 'check_in_date'
df_1 = pd.merge(df_1, date, how='left', left_on='check_in_date', right_on='date')
df_1.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25        30
# 1        19562    2022-05-01           RT1                   28        30
# 2        19563    2022-05-01           RT1                   23        30
# 3        17558    2022-05-01           RT1                   13        19
# 4        16558    2022-05-01           RT1                   18        19
#
#          date  mmm yy week no day_type
# 0  2022-05-01  May 22    W 19  weekend
# 1  2022-05-01  May 22    W 19  weekend
# 2  2022-05-01  May 22    W 19  weekend
# 3  2022-05-01  May 22    W 19  weekend
# 4  2022-05-01  May 22    W 19  weekend

# %%
# Let us drop 1 date and mm yy coloumns from above
df_1 = df_1.drop(columns = ['date','mmm yy'])
df_1.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25        30
# 1        19562    2022-05-01           RT1                   28        30
# 2        19563    2022-05-01           RT1                   23        30
#
#   week no day_type
# 0    W 19  weekend
# 1    W 19  weekend
# 2    W 19  weekend

# %%
# Now add hotel catogory and city from the dataframe hotel to the dataframe df_1

# %%
df_1 = pd.merge(df_1, hotels, how='left', left_on='property_id', right_on='property_id')
df_1.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559    2022-05-01           RT1                   25        30
# 1        19562    2022-05-01           RT1                   28        30
# 2        19563    2022-05-01           RT1                   23        30
#
#   week no day_type  property_name  category       city
# 0    W 19  weekend  Atliq Exotica    Luxury     Mumbai
# 1    W 19  weekend      Atliq Bay    Luxury  Bangalore
# 2    W 19  weekend   Atliq Palace  Business  Bangalore

# %%
# Add coloumns to df_2 dataframe.

# %%
# Merge based on 'date' and 'check_in_date'
df_2 = pd.merge(df_2, date, how='left', left_on='check_in_date', right_on='date')

# remove date and mmm yy coloumns
df_2 = df_2.drop(columns = ['date','mmm yy'])
df_2.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized week no day_type
# 0              10010             10010    W 19  weekend
# 1               9100              3640    W 19  weekend
# 2               9100              9100    W 19  weekend

# %%
df_2.tail()
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 134585    2022-08-03          1           RT4     makeyourtrip            2.0
# 134586    2022-08-01          4           RT4          logtrip            2.0
# 134587    2022-08-02          1           RT4         tripster            NaN
# 134588    2022-08-01          2           RT4          logtrip            2.0
# 134589    2022-08-01          2           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized week no day_type
# ...

# %%
# Now add hotel catogory and city from the dataframe hotel to the dataframe df_2

# %%
df_2 = pd.merge(df_2, hotels, how='left', left_on='property_id', right_on='property_id')
df_2.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized week no day_type property_name  \
# 0              10010             10010    W 19  weekend  Atliq Grands
# 1               9100              3640    W 19  weekend  Atliq Grands
# 2               9100              9100    W 19  weekend  Atliq Grands
#
#   category   city
# 0   Luxury  Delhi
# 1   Luxury  Delhi
# 2   Luxury  Delhi

# %%
# REVENUE ANALYSIS

# %%
# REVENUE
# Total revenue gerated and total revenue realised in each week
# Total revenue of each city in each week
# Total revenue of each property in each week
# Total revenue of each room catagory from all property in each week 
# Total revenue of each room catogory from each city in each week
# Total revenue of each room catogory of each property in each week

# %%
# Total revenue gerated in each week and total revenue realised

# %%
rev_gen = df_2.groupby('week no')['revenue_generated'].sum()
rev_gen
# Out:
# week no
# W 19    163172505
# W 20    163281645
# W 21    134713445
# W 22    163548270
# W 23    135292075
# W 24    164638555
# W 25    163551905
# W 26    134528520
# W 27    163604250
# W 28    163149400
# W 29    164451655
# W 30    134403455
# W 31    134659295
# W 32     24551240
# Name: revenue_generated, dtype: int64

# %%
rev_real = df_2.groupby('week no')['revenue_realized'].sum()
rev_real
# Out:
# week no
# W 19    138182064
# W 20    139435920
# W 21    114922175
# W 22    138720126
# W 23    115568569
# W 24    139581703
# W 25    138674279
# W 26    114152421
# W 27    139555632
# W 28    139383916
# W 29    139730590
# W 30    114811148
# W 31    115042325
# W 32     21010361
# Name: revenue_realized, dtype: int64

# %%
rev_dif = rev_gen -  rev_real 
rev_dif
# Out:
# week no
# W 19    24990441
# W 20    23845725
# W 21    19791270
# W 22    24828144
# W 23    19723506
# W 24    25056852
# W 25    24877626
# W 26    20376099
# W 27    24048618
# W 28    23765484
# W 29    24721065
# W 30    19592307
# W 31    19616970
# W 32     3540879
# dtype: int64

# %%
# Plotting
plt.figure(figsize=(8, 4))

# Plot 'rev_gen'
plt.plot(rev_gen.index, rev_gen, label='Revenue Generated')

# Plot 'rev_real'
plt.plot(rev_real.index, rev_real, label='Revenue Realised')

# Plot 'rev_dif'
plt.plot(rev_dif.index, rev_dif, label='Revenue Difference')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Revenue Comparison by Week')
plt.legend()

# Show the plot
plt.show()

# %%
# RESULT 
# High revenue on the weeks 19,20,22,24,25,27,28,29. [revenue generated > 15 cr] and [revenue real > 13 CR]
# This shows week 19 to 23 is for May, Week 23 to 27 to June and Week 27 to 32 for July.

# %%
#Check result
High_revenue = rev_gen>150000000
High_revenue
# Out:
# week no
# W 19     True
# W 20     True
# W 21    False
# W 22     True
# W 23    False
# W 24     True
# W 25     True
# W 26    False
# W 27     True
# W 28     True
# W 29     True
# W 30    False
# W 31    False
# W 32    False
# Name: revenue_generated, dtype: bool

# %%
# Check result
High_revenue = rev_real > 130000000
High_revenue
# Out:
# week no
# W 19     True
# W 20     True
# W 21    False
# W 22     True
# W 23    False
# W 24     True
# W 25     True
# W 26    False
# W 27     True
# W 28     True
# W 29     True
# W 30    False
# W 31    False
# W 32    False
# Name: revenue_realized, dtype: bool

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------

# %%
# Total revenue of each City in each week

# %%
# Create dataframe for each city
# Sub dataframe from df_2
Del = df_2[df_2['city'] == "Delhi"]
Mum = df_2[df_2['city'] == "Mumbai"]
Hyd = df_2[df_2['city'] == "Hyderabad"]
Ban = df_2[df_2['city'] == "Bangalore"]

# %%
Del.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized week no day_type property_name  \
# ...

# %%
Mum.head()
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 50  May012216559RT11        16559   2022-04-28    2022-05-01    2022-05-03
# 51  May012216559RT12        16559   2022-04-29    2022-05-01    2022-05-06
# 52  May012216559RT13        16559   2022-04-27    2022-05-01    2022-05-02
# 53  May012216559RT14        16559   2022-04-29    2022-05-01    2022-05-03
# 54  May012216559RT15        16559   2022-04-29    2022-05-01    2022-05-02
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 50          2           RT1          journey            3.0    Checked Out
# 51          2           RT1     makeyourtrip            5.0    Checked Out
# 52          1           RT1         tripster            NaN      Cancelled
# 53          3           RT1   direct offline            5.0    Checked Out
# 54          3           RT1           others            5.0    Checked Out
#
# ...

# %%
Hyd.head()
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 935  May012218558RT11        18558   2022-04-28    2022-05-01    2022-05-02
# 936  May012218558RT12        18558   2022-04-30    2022-05-01    2022-05-02
# 937  May012218558RT13        18558   2022-04-28    2022-05-01    2022-05-05
# 938  May012218558RT14        18558   2022-04-30    2022-05-01    2022-05-06
# 939  May012218558RT15        18558   2022-04-27    2022-05-01    2022-05-03
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 935          3           RT1     makeyourtrip            3.0    Checked Out
# 936          2           RT1           others            NaN    Checked Out
# 937          2           RT1         tripster            3.0    Checked Out
# 938          2           RT1   direct offline            3.0    Checked Out
# 939          2           RT1           others            3.0    Checked Out
#
# ...

# %%
Ban.head()
# Out:
#             booking_id  property_id booking_date check_in_date checkout_date  \
# 1457  May012219558RT11        19558   2022-04-07    2022-05-01    2022-05-02
# 1458  May012219558RT12        19558   2022-04-26    2022-05-01    2022-05-06
# 1459  May012219558RT13        19558   2022-04-27    2022-05-01    2022-05-02
# 1460  May012219558RT14        19558   2022-04-10    2022-05-01    2022-05-02
# 1461  May012219558RT15        19558   2022-04-27    2022-05-01    2022-05-02
#
#       no_guests room_category booking_platform  ratings_given booking_status  \
# 1457          2           RT1           others            2.0    Checked Out
# 1458          2           RT1     makeyourtrip            4.0    Checked Out
# 1459          2           RT1           others            3.0    Checked Out
# 1460          2           RT1          logtrip            2.0    Checked Out
# 1461          2           RT1           others            NaN    Checked Out
#
# ...

# %%
# Revenue generated by each city in each week
Del_rev_gen = Del.groupby('week no')["revenue_generated"].sum()
Mum_rev_gen = Mum.groupby('week no')["revenue_generated"].sum()
Hyd_rev_gen = Hyd.groupby('week no')["revenue_generated"].sum()
Ban_rev_gen = Ban.groupby('week no')["revenue_generated"].sum()

# %%
# Revenue realised by each city in each week
Del_rev_real = Del.groupby('week no')["revenue_realized"].sum()
Mum_rev_real = Mum.groupby('week no')["revenue_realized"].sum()
Hyd_rev_real = Hyd.groupby('week no')["revenue_realized"].sum()
Ban_rev_real = Ban.groupby('week no')["revenue_realized"].sum()

# %%
# Difference in revenue generated and revenue realised
Del_rev_dif = Del_rev_gen - Del_rev_real
Mum_rev_dif = Mum_rev_gen - Mum_rev_real
Hyd_rev_dif = Hyd_rev_gen - Hyd_rev_real
Ban_rev_dif = Ban_rev_gen - Ban_rev_real

# %%
# Plotting Delhi Week Wise Revenue
plt.figure(figsize=(8, 4))

# Plot 'rev_gen'
plt.plot(Del_rev_gen.index, Del_rev_gen, label='Revenue Generated')

# Plot 'rev_real'
plt.plot(Del_rev_real.index, Del_rev_real, label='Revenue Realised')

# Plot 'rev_dif'
plt.plot(Del_rev_dif.index, Del_rev_dif, label='Revenue Difference')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Revenue Comparison by Week Delhi')
plt.legend()

# Show the plot
plt.show()

# %%
# Plotting Week Wise Revenue for Delhi, Mumbai, Hyderabad, and Bangalore

plt.figure(figsize=(16, 8))  

# Subplot 1: Delhi
plt.subplot(2, 2, 1)

# Plot 'rev_gen'
plt.plot(Del_rev_gen.index, Del_rev_gen, label='Revenue Generated')
# Plot 'rev_real'
plt.plot(Del_rev_real.index, Del_rev_real, label='Revenue Realised')
# Plot 'rev_dif'
plt.plot(Del_rev_dif.index, Del_rev_dif, label='Revenue Difference')

# Adding labels and title for subplot 1
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Delhi Revenue Comparison by Week')
plt.legend()

# Subplot 2: Mumbai
plt.subplot(2, 2, 2)

# Plot 'rev_gen'
plt.plot(Mum_rev_gen.index, Mum_rev_gen, label='Revenue Generated')
# Plot 'rev_real'
plt.plot(Mum_rev_real.index, Mum_rev_real, label='Revenue Realised')
# Plot 'rev_dif'
plt.plot(Mum_rev_dif.index, Mum_rev_dif, label='Revenue Difference')

# Adding labels and title for subplot 2
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Mumbai Revenue Comparison by Week')
plt.legend()

# Subplot 3: Hyderabad
plt.subplot(2, 2, 3)

# Plot 'rev_gen'
plt.plot(Hyd_rev_gen.index, Hyd_rev_gen, label='Revenue Generated')
# Plot 'rev_real'
plt.plot(Hyd_rev_real.index, Hyd_rev_real, label='Revenue Realised')
# Plot 'rev_dif'
plt.plot(Hyd_rev_dif.index, Hyd_rev_dif, label='Revenue Difference')

# Adding labels and title for subplot 3
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Hyderabad Revenue Comparison by Week')
plt.legend()

# Subplot 4: Bangalore
plt.subplot(2, 2, 4)

# Plot 'rev_gen'
plt.plot(Ban_rev_gen.index, Ban_rev_gen, label='Revenue Generated')
# Plot 'rev_real'
plt.plot(Ban_rev_real.index, Ban_rev_real, label='Revenue Realised')
# Plot 'rev_dif'
plt.plot(Ban_rev_dif.index, Ban_rev_dif, label='Revenue Difference')

# Adding labels and title for subplot 4
plt.xlabel('Week Number')
plt.ylabel('Revenue')
plt.title('Bangalore Revenue Comparison by Week')
plt.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
# RESULT 
# The week wise revenue distribution of all cities are in same pattern.

# %% [markdown]
# -----------------------------
# -------------------------------

# %%
# Total revenue of each property in each week

# %%
## Total revenue of each property in Delhi each week

# %%
Del['property_id'].unique()
# Out:
# array([16558, 16560, 16561, 16562, 16563], dtype=int64)

# %%
Del_prop_rev_gen_week = Del.groupby(["property_id","week no"])["revenue_generated"].sum().reset_index()

# %%
Del_prop_rev_gen_week
# Out:
#     property_id week no  revenue_generated
# 0         16558    W 19            3456670
# 1         16558    W 20            3352510
# 2         16558    W 21            2757230
# 3         16558    W 22            3441270
# 4         16558    W 23            2849000
# ..          ...     ...                ...
# 65        16563    W 28            8267280
# 66        16563    W 29            8400490
# 67        16563    W 30            7123900
# 68        16563    W 31            7147980
# 69        16563    W 32            1329720
#
# [70 rows x 3 columns]

# %%
# Plot revenue generated in each week by each property in Delhi 
# Get unique property_ids
Del_unique_property_ids = Del_prop_rev_gen_week['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(6, 4))

for property_id in Del_unique_property_ids:
    # Filter data for the current property_id
    property_data = Del_prop_rev_gen_week[Del_prop_rev_gen_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_generated'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated in Week by Each Property in Delhi')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
Del_prop_rev_real_week = Del.groupby(["property_id","week no"])["revenue_realized"].sum().reset_index()

# %%
Del_prop_rev_real_week
# Out:
#     property_id week no  revenue_realized
# 0         16558    W 19           2909830
# 1         16558    W 20           2935450
# 2         16558    W 21           2330258
# 3         16558    W 22           2999766
# 4         16558    W 23           2400146
# ..          ...     ...               ...
# 65        16563    W 28           7035504
# 66        16563    W 29           7108780
# 67        16563    W 30           6080452
# 68        16563    W 31           6093528
# 69        16563    W 32           1098930
#
# [70 rows x 3 columns]

# %%
# Plot revenue realized in each week by each property in Delhi 

plt.figure(figsize=(6, 4))

for property_id in Del_unique_property_ids:
    # Filter data for the current property_id
    property_data = Del_prop_rev_real_week[Del_prop_rev_real_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_realized'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized In Week By Each Property in Delhi')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# Result 
# The property 16561 generated low revenue in week 25 compared to week 24.
# Whereas all other properties generated high revenue on in week 25 compared to week 24.

# %%
## Total revenue of each property in Mumbai each week

# %%
Mum_prop_rev_gen_week = Mum.groupby(["property_id","week no"])["revenue_generated"].sum().reset_index()
Mum_prop_rev_real_week = Mum.groupby(["property_id","week no"])["revenue_realized"].sum().reset_index()

# %%
# Plot revenue generated in each week by each property in Mumbai
# Get unique property_ids
Mum_unique_property_ids = Mum_prop_rev_gen_week['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Mum_unique_property_ids:
    # Filter data for the current property_id
    property_data = Mum_prop_rev_gen_week[Mum_prop_rev_gen_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_generated'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated in Week for Each Property in Mumbai')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# Plot revenue realized in each week by each property in Mumbai

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Mum_unique_property_ids:
    # Filter data for the current property_id
    property_data = Mum_prop_rev_real_week[Mum_prop_rev_real_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_realized'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized in Week for Each Property in Mumbai')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
## Total revenue in each week by each property in Hyderabad

# %%
Hyd_prop_rev_gen_week = Hyd.groupby(["property_id","week no"])["revenue_generated"].sum().reset_index()
Hyd_prop_rev_real_week = Hyd.groupby(["property_id","week no"])["revenue_realized"].sum().reset_index()

# %%
# Plot revenue generated in each week by each property in Hyderabad
# Get unique property_ids
Hyd_unique_property_ids = Hyd_prop_rev_gen_week['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Hyd_unique_property_ids:
    # Filter data for the current property_id
    property_data = Hyd_prop_rev_gen_week[Hyd_prop_rev_gen_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_generated'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated in Week for Each Property in Hyderabad')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# Plot revenue realized in each week by each property in Hyderabad 

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Hyd_unique_property_ids:
    # Filter data for the current property_id
    property_data = Hyd_prop_rev_real_week[Hyd_prop_rev_real_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_realized'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized in Week for Each Property in Hyderabad')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
## Total revenue in each week by each property in Bangalore

# %%
Ban_prop_rev_gen_week = Ban.groupby(["property_id","week no"])["revenue_generated"].sum().reset_index()
Ban_prop_rev_real_week = Ban.groupby(["property_id","week no"])["revenue_realized"].sum().reset_index()

# %%
# Plot revenue generated in each week by each property in Bangalore

# Get unique property_ids
Ban_unique_property_ids = Ban_prop_rev_gen_week['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Ban_unique_property_ids:
    # Filter data for the current property_id
    property_data = Ban_prop_rev_gen_week[Ban_prop_rev_gen_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_generated'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated in Week for Each Property in Bangalore')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# Plot revenue realized in each week by each property in Bangalore

# Plotting each property_id separately
plt.figure(figsize=(8, 6))

for property_id in Ban_unique_property_ids:
    # Filter data for the current property_id
    property_data = Ban_prop_rev_real_week[Ban_prop_rev_real_week['property_id'] == property_id]
    
    # Plot the data
    plt.plot(property_data['week no'], property_data['revenue_realized'], label=f'Property {property_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized in Week for Each Property in Bangalore')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %% [markdown]
# -----------------

# %% [markdown]
# -----------

# %%
# Total revenue of each room catagory from all property in each week
# Whole dataframe df_2 ---> room catogory ----> week wise ----> revenue

# %%
df_2.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized week no day_type property_name  \
# ...

# %%
room_rev_gen_week = df_2.groupby(['room_category','week no'])['revenue_generated'].sum().reset_index()

# %%
print(room_rev_gen_week.head(3))
print(room_rev_gen_week.tail(3))
# Out:
#   room_category week no  revenue_generated
# 0           RT1    W 19           29469505
# 1           RT1    W 20           29737045
# 2           RT1    W 21           24351405
#    room_category week no  revenue_generated
# 53           RT4    W 30           29416940
# 54           RT4    W 31           29424350
# 55           RT4    W 32            5459080

# %%
# Get unique room_categories
unique_room_categories = room_rev_gen_week['room_category'].unique()

# Plotting each room_category separately
plt.figure(figsize=(6, 4))

for room_category in unique_room_categories:
    # Filter data for the current room_category
    category_data = room_rev_gen_week[room_rev_gen_week['room_category'] == room_category]
    
    # Plot the data
    plt.plot(category_data['week no'], category_data['revenue_generated'], label=f'Room Category {room_category}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated by Week for Each Room Category')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
room_rev_real_week = df_2.groupby(['room_category','week no'])['revenue_realized'].sum().reset_index()

# %%
# Plotting each room_category separately
plt.figure(figsize=(6, 4))

for room_category in unique_room_categories:
    # Filter data for the current room_category
    category_data = room_rev_real_week[room_rev_real_week['room_category'] == room_category]
    
    # Plot the data
    plt.plot(category_data['week no'], category_data['revenue_realized'], label=f'Room Category {room_category}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized by Week for Each Room Category')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# RESULT 
# Catogory 1 and 4 (Standard and Presidential Rooms) contributes less to revenue. 
# Catogory 3 (Premium Rooms) contributed high revenue in all weeks

# %% [markdown]
# ----------------------------------

# %% [markdown]
# -------------

# %%
# Total revenue of each room catogory from each city in each week
# city dataframe  --->groupby ---->room catogory, week no -----> sum revenue

# %%
## Total revenue of each room catogory of Delhi in each week

# %%
Del.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized week no day_type property_name  \
# 0              10010             10010    W 19  weekend  Atliq Grands
# 1               9100              3640    W 19  weekend  Atliq Grands
#
#   category   city
# 0   Luxury  Delhi
# 1   Luxury  Delhi

# %%
Del_room_rev_gen_week = Del.groupby(["room_category","week no"])["revenue_generated"].sum().reset_index()
Del_room_rev_real_week = Del.groupby(["room_category","week no"])["revenue_realized"].sum().reset_index()

# %%
print(Del_room_rev_gen_week.head(3))
print(Del_room_rev_gen_week.tail(3))
# Out:
#   room_category week no  revenue_generated
# 0           RT1    W 19            6068790
# 1           RT1    W 20            6036940
# 2           RT1    W 21            4969510
#    room_category week no  revenue_generated
# 53           RT4    W 30            4867800
# 54           RT4    W 31            4798640
# 55           RT4    W 32             856520

# %%
print(Del_room_rev_real_week.head(3))
print(Del_room_rev_real_week.tail(3))
# Out:
#   room_category week no  revenue_realized
# 0           RT1    W 19           5182632
# 1           RT1    W 20           4999540
# 2           RT1    W 21           4143958
#    room_category week no  revenue_realized
# 53           RT4    W 30           4168752
# 54           RT4    W 31           4219292
# 55           RT4    W 32            677768

# %%
# Plot revenue generated in each week by each room catogory in Delhi

# Get unique property_ids
Del_unique_room_ids = Del_room_rev_gen_week['room_category'].unique()

# Plotting each property_id separately
plt.figure(figsize=(6,4))

for room_id in Del_unique_room_ids:
    # Filter data for the current property_id
    room_data = Del_room_rev_gen_week[Del_room_rev_gen_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_generated'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.title('Revenue Generated in Week for Each Room in Delhi')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
# Result
# RT3 and RT4 generated more revenue in week 25 compared to week 24.
# Whereas RT1 and RT2 catogory rooms generated low revenue in week 25 campared to week 24.

# %%
# Plot revenue realized in each week by each room catogory in Delhi


# Plotting each property_id separately
plt.figure(figsize=(6,4))

for room_id in Del_unique_room_ids:
    # Filter data for the current property_id
    room_data = Del_room_rev_real_week[Del_room_rev_real_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_realized'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Realized')
plt.title('Revenue Realized in Week for Each Room in Delhi')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')

# Show the plot
plt.show()

# %%
## Total revenue of each room catogory of Mumbai in each week

# %%
Mum_room_rev_gen_week = Mum.groupby(["room_category","week no"])["revenue_generated"].sum().reset_index()
Mum_room_rev_real_week = Mum.groupby(["room_category","week no"])["revenue_realized"].sum().reset_index()

# %%
# Plot revenue generated and revenue realized in each week by each room catogory in Mumbai

# Get unique property_ids
Mum_unique_room_ids = Mum_room_rev_gen_week['room_category'].unique()

# Plotting each property_id separately
plt.figure(figsize=(9,5))
 

# Subplot 1: Revenue Generated
plt.subplot(1, 2, 1)

for room_id in Mum_unique_room_ids:
    # Filter data for the current property_id
    room_data = Mum_room_rev_gen_week[Mum_room_rev_gen_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_generated'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Subplot 2: Revenue realized
plt.subplot(1, 2, 2)


for room_id in Mum_unique_room_ids:
    # Filter data for the current property_id
    room_data = Mum_room_rev_real_week[Mum_room_rev_real_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_realized'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel("Revenue Realized")
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Add a common title above subplots
plt.suptitle('Comparison of Revenue Generated and Realized for Each Room  Category in Each Week in Mumbai', y=1, fontsize=10)




# Show the plot
plt.show()

# %%
## Total revenue of each room catogory of Hyderabad in each week

# %%
Hyd_room_rev_gen_week = Hyd.groupby(["room_category","week no"])["revenue_generated"].sum().reset_index()
Hyd_room_rev_real_week = Hyd.groupby(["room_category","week no"])["revenue_realized"].sum().reset_index()


# Plot revenue generated and revenue realized in each week by each room catogory in Hyderabad

# Get unique property_ids
Hyd_unique_room_ids = Hyd_room_rev_gen_week['room_category'].unique()

# Plotting each property_id separately
plt.figure(figsize=(9,5))
 

# Subplot 1: Revenue Generated
plt.subplot(1, 2, 1)

for room_id in Hyd_unique_room_ids:
    # Filter data for the current property_id
    room_data = Hyd_room_rev_gen_week[Hyd_room_rev_gen_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_generated'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Subplot 2: Revenue realized
plt.subplot(1, 2, 2)


for room_id in Hyd_unique_room_ids:
    # Filter data for the current property_id
    room_data = Hyd_room_rev_real_week[Hyd_room_rev_real_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_realized'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel("Revenue Realized")
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Add a common title above subplots
plt.suptitle('Comparison of Revenue Generated and Realized for Each Room  Category in Each Week in Hyderabad', y=1, fontsize=10)




# Show the plot
plt.show()

# %%
## Total revenue of each room catogory of Bangalore in each week

# %%
Ban_room_rev_gen_week = Ban.groupby(["room_category","week no"])["revenue_generated"].sum().reset_index()
Ban_room_rev_real_week = Ban.groupby(["room_category","week no"])["revenue_realized"].sum().reset_index()


# Plot revenue generated and revenue realized in each week by each room catogory in Bangalore

# Get unique property_ids
Ban_unique_room_ids = Ban_room_rev_gen_week['room_category'].unique()

# Plotting each property_id separately
plt.figure(figsize=(9,5))
 

# Subplot 1: Revenue Generated
plt.subplot(1, 2, 1)

for room_id in Ban_unique_room_ids:
    # Filter data for the current property_id
    room_data = Ban_room_rev_gen_week[Ban_room_rev_gen_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_generated'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel('Revenue Generated')
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Subplot 2: Revenue realized
plt.subplot(1, 2, 2)


for room_id in Ban_unique_room_ids:
    # Filter data for the current property_id
    room_data = Ban_room_rev_real_week[Ban_room_rev_real_week['room_category'] == room_id]
    
    # Plot the data
    plt.plot(room_data['week no'], room_data['revenue_realized'], label=f'room {room_id}')

# Adding labels and title
plt.xlabel('Week Number')
plt.ylabel("Revenue Realized")
plt.legend()

# Rotate week numbers vertically on the x-axis
plt.xticks(rotation='vertical')


# Add a common title above subplots
plt.suptitle('Comparison of Revenue Generated and Realized for Each Room  Category in Each Week in Bangalore', y=1, fontsize=10)




# Show the plot
plt.show()

# %% [markdown]
# ------------------------

# %% [markdown]
# ------------

# %%
# Total revenue of each room catogory of each property in each week 
# city ---->group by (property , room catogory, week) ---->sum revenue

# %%
## Total revenue of each room catogory of each property in each week in Delhi

# %%
Del_prop_room_rev_gen_week = Del.groupby(["property_id","week no",'room_category'])["revenue_generated"].sum().reset_index()

# %%
Del_prop_room_rev_gen_week
# Out:
#      property_id week no room_category  revenue_generated
# 0          16558    W 19           RT1             903630
# 1          16558    W 19           RT2            1411200
# 2          16558    W 19           RT3             705600
# 3          16558    W 19           RT4             436240
# 4          16558    W 20           RT1             876330
# ..           ...     ...           ...                ...
# 275        16563    W 31           RT4            1952440
# 276        16563    W 32           RT1             318500
# 277        16563    W 32           RT2             409500
# 278        16563    W 32           RT3             245280
# 279        16563    W 32           RT4             356440
#
# [280 rows x 4 columns]

# %%
# Get unique property_ids
unique_property_ids = Del['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(15, 10))

for i, property_id in enumerate(unique_property_ids, start=1):
    # Subplot for each property_id
    plt.subplot(2, 3, i)
    
    # Filter data for the current property_id
    property_data = Del_prop_room_rev_gen_week[Del_prop_room_rev_gen_week['property_id'] == property_id]
    
    # Plot the data for each room category
    for room_category in ['RT1', 'RT2', 'RT3', 'RT4']:
        room_data = property_data[property_data['room_category'] == room_category]
        plt.plot(room_data['week no'], room_data['revenue_generated'], label=room_category)

    # Adding labels and title
    plt.xlabel('Week Number')
    plt.ylabel('Revenue Generated')
    plt.title(f'Revenue Generated for Property ID {property_id}')
    plt.legend()

    # Rotate week numbers vertically on the x-axis
    plt.xticks(rotation='vertical')

# Adjust layout for better appearance
plt.tight_layout()

# Show the plot
plt.show()

# %%
## Total revenue of each room catogory of each property in each week in Mumbai

# %%
Mum_prop_room_rev_gen_week = Mum.groupby(["property_id","week no",'room_category'])["revenue_generated"].sum().reset_index()

# %%
Mum['property_id'].nunique()
# Out:
# 8

# %%
# Get unique property_ids
unique_property_ids = Mum['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(12, 18))

for i, property_id in enumerate(unique_property_ids, start=1):
    # Subplot for each property_id
    plt.subplot(4, 2, i)
    
    # Filter data for the current property_id
    property_data = Mum_prop_room_rev_gen_week[Mum_prop_room_rev_gen_week['property_id'] == property_id]
    
    # Plot the data for each room category
    for room_category in ['RT1', 'RT2', 'RT3', 'RT4']:
        room_data = property_data[property_data['room_category'] == room_category]
        plt.plot(room_data['week no'], room_data['revenue_generated'], label=room_category)

    # Adding labels and title
    plt.xlabel('Week Number')
    plt.ylabel('Revenue Generated')
    plt.title(f'Revenue Generated for Property ID {property_id}')
    plt.legend()

    # Rotate week numbers vertically on the x-axis
    plt.xticks(rotation='vertical')

# Adjust layout for better appearance
plt.tight_layout()

# Show the plot
plt.show()

# %%
## Total revenue of each room catogory of each property in each week in Hyderabad

# %%
Hyd_prop_room_rev_gen_week = Hyd.groupby(["property_id","week no",'room_category'])["revenue_generated"].sum().reset_index()

# %%
Hyd['property_id'].nunique()
# Out:
# 6

# %%
# Get unique property_ids
unique_property_ids = Hyd['property_id'].unique()

# Plotting each property_id separately
plt.figure(figsize=(12, 10))

for i, property_id in enumerate(unique_property_ids, start=1):
    # Subplot for each property_id
    plt.subplot(3, 2, i)
    
    # Filter data for the current property_id
    property_data = Hyd_prop_room_rev_gen_week[Hyd_prop_room_rev_gen_week['property_id'] == property_id]
    
    # Plot the data for each room category
    for room_category in ['RT1', 'RT2', 'RT3', 'RT4']:
        room_data = property_data[property_data['room_category'] == room_category]
        plt.plot(room_data['week no'], room_data['revenue_generated'], label=room_category)

    # Adding labels and title
    plt.xlabel('Week Number')
    plt.ylabel('Revenue Generated')
    plt.title(f'Revenue Generated for Property ID {property_id}')
    plt.legend()

    # Rotate week numbers vertically on the x-axis
    plt.xticks(rotation='vertical')

# Adjust layout for better appearance
plt.tight_layout()

# Show the plot
plt.show()
